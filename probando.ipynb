# %%
# pip freeze (mirar todas las librerias instaladas)
# pip freeze | grep numpy  (mirar que libreria especifica esta instalada en Linux en este caso numpy)
# pip freeze | findstr numpy (mirar que libreria especifica esta instalada en Windows en este caso numpy)
# correr en la consola ya que es un comando de sistema operativo
# Out:
# absl-py==2.3.1
# antlr4-python3-runtime==4.7.2
# anyio==4.9.0
# argon2-cffi==25.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.3.0
# asttokens==3.0.0
# astunparse==1.6.3
# async-lru==2.0.5
# attrs==25.3.0
# babel==2.17.0
# beautifulsoup4==4.13.4
# bleach==6.2.0
# blinker==1.9.0
# certifi==2025.7.14
# cffi==1.17.1
# charset-normalizer==3.4.2
# click==8.1.8
# colorama==0.4.6
# comm==0.2.2
# contourpy==1.3.1
# cycler==0.12.1
# debugpy==1.8.12
# decorator==5.1.1
# defusedxml==0.7.1
# et_xmlfile==2.0.0
# executing==2.2.0
# fastjsonschema==2.21.1
# Flask==3.1.0
# flatbuffers==25.9.23
# fonttools==4.56.0
# fqdn==1.5.1
# gast==0.6.0
# google-pasta==0.2.0
# grpcio==1.76.0
# h11==0.16.0
# h5py==3.15.1
# httpcore==1.0.9
# httpx==0.28.1
# idna==3.10
# ipykernel==6.29.5
# ipython==8.32.0
# ipywidgets==8.1.7
# isoduration==20.11.0
# itsdangerous==2.2.0
# jedi==0.19.2
# Jinja2==3.1.5
# json5==0.12.0
# jsonpointer==3.0.0
# jsonschema==4.25.0
# jsonschema-specifications==2025.4.1
# ...

# %%
print(0.1 + 0.2) # error de punto flotante
# Out:
# 0.30000000000000004
